# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#attempting to calculate for an individual player 
f = open('degrom.txt','r')
pitches = []
for x in f:
    pitches.append(x.split("	"))
    
xOBP = 0

OBPmatrix = [[.354,.326,.157,0],
            [.336,.344,.164,0],
            [.353,.341,.180,0],
            [.927,.714,.456,0],
             [1,1,1,0]]

BIP = .326
    
for pit in pitches:
    print(pit[10], pit[12])
    if 'strike' in pit[12]:
        print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])+1], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])] )
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'foul' in pit[12] and pit[10][2] != 2:
        print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])+1], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])] )
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'ball' in pit[12]:
        print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])+1][int(pit[10][2])])
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'hit' in pit[12]:
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - BIP
        
print(xOBP)
# Out:
# 3-2 called_strike
# 0.456 0 -0.544
# 2-2 ball
# 0.18 0.456
# 2-1 foul
# 0.341 0.18 -0.37299999999999994
# 1-1 ball
# 0.344 0.341
# 1-0 swinging_strike
# 0.336 0.344 -0.01699999999999996
# 0-0 ball
# 0.354 0.336
# 2-0 hit_into_play
# 1-0 ball
# 0.336 0.353
# 0-0 ball
# 0.354 0.336
# 2-2 swinging_strike
# 0.18 0 -0.276
# 2-2 foul
# 0.18 0 -0.276
# 2-1 swinging_strike
# 0.341 0.18 -0.37299999999999994
# 2-0 called_strike
# 0.353 0.341 -0.5740000000000001
# 1-0 ball
# 0.336 0.353
# 0-0 ball
# 0.354 0.336
# 0-0 hit_into_play
# 0-0 hit_into_play
# 3-2 hit_into_play
# 3-2 foul
# 0.456 0 -0.544
# 3-1 foul_tip
# 0.714 0.456 -0.28600000000000003
# 2-1 ball
# 0.341 0.714
# 2-0 called_strike
# 0.353 0.341 -0.5740000000000001
# 1-0 ball
# 0.336 0.353
# 0-0 ball
# 0.354 0.336
# 1-2 hit_into_play
# 1-2 foul
# 0.164 0 -0.015999999999999986
# 0-2 ball
# 0.157 0.164
# 0-1 called_strike
# 0.326 0.157 -0.01799999999999996
# 0-0 called_strike
# 0.354 0.326 0.01799999999999996
# 0-2 swinging_strike
# ...

# %%
#calculatng for another successful pitcher, Cy Young winner Corbin Burnes
f = open('Burnes.txt','r')
pitches = []
for x in f:
    pitches.append(x.split("	"))
    
xOBP = 0

OBPmatrix = [[.354,.326,.157,0],
            [.336,.344,.164,0],
            [.353,.341,.180,0],
            [.927,.714,.456,0],
            [1,1,1,0]]

BIP = .326
    
for pit in pitches:
    print(pit[10], pit[12])
    if 'strike' in pit[12]:
        print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])+1], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])] )
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'foul' in pit[12] and pit[10][2] != 2:
        print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])+1], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])] )
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'ball' in pit[12]:
        print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])+1][int(pit[10][2])])
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'hit' in pit[12]:
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - BIP
        
print(round(xOBP,3))
# Out:
# 0-2 foul_tip
# 0.157 0 -0.007000000000000006
# 0-1 foul
# 0.326 0.157 -0.01799999999999996
# 0-0 foul
# 0.354 0.326 0.01799999999999996
# 2-2 swinging_strike
# 0.18 0 -0.276
# 1-2 ball
# 0.164 0.18
# 1-2 foul
# 0.164 0 -0.015999999999999986
# 1-2 foul
# 0.164 0 -0.015999999999999986
# 0-2 ball
# 0.157 0.164
# 0-1 called_strike
# 0.326 0.157 -0.01799999999999996
# 0-0 called_strike
# 0.354 0.326 0.01799999999999996
# 0-1 hit_into_play
# 0-0 called_strike
# 0.354 0.326 0.01799999999999996
# 1-2 swinging_strike_blocked
# 0.164 0 -0.015999999999999986
# 0-2 ball
# 0.157 0.164
# 0-1 called_strike
# 0.326 0.157 -0.01799999999999996
# 0-0 called_strike
# 0.354 0.326 0.01799999999999996
# 3-1 hit_into_play
# 3-0 called_strike
# 0.927 0.714 -0.07299999999999995
# 2-0 ball
# 0.353 0.927
# 1-0 blocked_ball
# 0.336 0.353
# 0-0 blocked_ball
# 0.354 0.336
# 3-1 ball
# 0.714 1
# 2-1 ball
# 0.341 0.714
# 1-1 ball
# 0.344 0.341
# 0-1 ball
# 0.326 0.344
# 0-0 called_strike
# ...

# %%
#calculating for bad pitcher, highest ERA Jordan Lyles
f = open('lyles.txt','r')
pitches = []
for x in f:
    pitches.append(x.split("	"))
    
xOBP = 0

OBPmatrix = [[.354,.326,.157,0],
            [.336,.344,.164,0],
            [.353,.341,.180,0],
            [.927,.714,.456,0],
            [1,1,1,0]]

BIP = .326
    
for pit in pitches:
    print(pit[10], pit[12])
    if 'strike' in pit[12]:
        print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])+1], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])] )
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'foul' in pit[12] and pit[10][2] != 2:
        print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])+1], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])] )
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'ball' in pit[12]:
        print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])+1][int(pit[10][2])])
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'hit' in pit[12]:
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - BIP
        
print(xOBP)
# Out:
# 0-2 hit_into_play
# 0-1 foul
# 0.326 0.157 -0.01799999999999996
# 0-0 called_strike
# 0.354 0.326 0.01799999999999996
# 3-2 swinging_strike
# 0.456 0 -0.544
# 2-2 ball
# 0.18 0.456
# 1-2 ball
# 0.164 0.18
# 0-2 ball
# 0.157 0.164
# 0-1 foul_tip
# 0.326 0.157 -0.01799999999999996
# 0-0 called_strike
# 0.354 0.326 0.01799999999999996
# 3-2 hit_into_play
# 3-2 foul
# 0.456 0 -0.544
# 3-1 foul
# 0.714 0.456 -0.28600000000000003
# 2-1 ball
# 0.341 0.714
# 2-0 called_strike
# 0.353 0.341 -0.5740000000000001
# 1-0 ball
# 0.336 0.353
# 0-0 ball
# 0.354 0.336
# 2-1 hit_into_play
# 1-1 ball
# 0.344 0.341
# 1-0 swinging_strike
# 0.336 0.344 -0.01699999999999996
# 0-0 ball
# 0.354 0.336
# 1-2 hit_into_play
# 0-2 ball
# 0.157 0.164
# 0-1 called_strike
# 0.326 0.157 -0.01799999999999996
# 0-0 called_strike
# 0.354 0.326 0.01799999999999996
# 2-2 foul_tip
# 0.18 0 -0.276
# 2-2 foul
# 0.18 0 -0.276
# 2-2 foul
# 0.18 0 -0.276
# 2-2 foul
# 0.18 0 -0.276
# 2-1 foul
# 0.341 0.18 -0.37299999999999994
# ...

# %%
#Calculating for a hitter, Freedie Freeman
t = open('freeman.txt','r')
newlist = []
for a in t:
    if a[1].isnumeric():
        #print(a)
        continue
    #print(a.split("	"))
    newlist.append(a.split("	"))

#print(newlist)
  
xOBP = 0

OBPmatrix = [[.354,.326,.157,0],
            [.336,.344,.164,0],
            [.353,.341,.180,0],
            [.927,.714,.456,0],
            [1,1,1,0]]

BIP = .326
    
for pit in newlist:
    if len(pit[0]) != 2:
        continue
    print(pit[10], pit[12])
    if 'strike' in pit[12]:
        print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])+1], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])] )
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'foul' in pit[12] and pit[10][2] != 2:
        print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])+1], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])] )
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'ball' in pit[12]:
        print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])+1][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])])
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'hit' in pit[12]:
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - BIP
        
print(xOBP)
# Out:
# 2-2 hit_into_play
# 2-1 foul
# 0.341 0.18 -0.37299999999999994
# 2-0 called_strike
# 0.353 0.341 -0.5740000000000001
# 1-0 ball
# 0.336 0.353 -0.01699999999999996
# 0-0 ball
# 0.354 0.336 0.01799999999999996
# 0-1 hit_into_play
# 0-0 foul
# 0.354 0.326 0.01799999999999996
# 2-1 hit_into_play
# 2-0 called_strike
# 0.353 0.341 -0.5740000000000001
# 1-0 ball
# 0.336 0.353 -0.01699999999999996
# 0-0 ball
# 0.354 0.336 0.01799999999999996
# 3-1 ball
# 0.714 1 -0.28600000000000003
# 2-1 ball
# 0.341 0.714 -0.37299999999999994
# 1-1 ball
# 0.344 0.341 0.002999999999999947
# 0-1 ball
# 0.326 0.344 -0.01799999999999996
# 0-0 called_strike
# 0.354 0.326 0.01799999999999996
# 1-1 hit_into_play
# 0-1 ball
# 0.326 0.344 -0.01799999999999996
# 0-0 swinging_strike
# 0.354 0.326 0.01799999999999996
# 1-2 hit_into_play
# 1-1 swinging_strike
# 0.344 0.164 0.002999999999999947
# 0-1 ball
# 0.326 0.344 -0.01799999999999996
# 0-0 called_strike
# 0.354 0.326 0.01799999999999996
# 1-0 hit_into_play
# ...

# %%
#Calculating for another successful hitter Vladimir Guerrero Jr.
t = open('vald.txt','r')
newlist = []
for a in t:
    if a[1].isnumeric():
        #print(a)
        continue
    #print(a.split("	"))
    newlist.append(a.split("	"))

#print(newlist)
  
xOBP = 0

OBPmatrix = [[.354,.326,.157,0],
            [.336,.344,.164,0],
            [.353,.341,.180,0],
            [.927,.714,.456,0],
            [1,1,1,0]]

BIP = .326
    
for pit in newlist:
    if len(pit[0]) != 2:
        continue
    #print(pit[10], pit[12])
    if 'strike' in pit[12]:
        #print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])+1], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])] )
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'foul' in pit[12] and pit[10][2] != 2:
        #print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])+1], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])] )
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'ball' in pit[12]:
        #print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])+1][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])])
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'hit' in pit[12]:
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - BIP
        
print(xOBP)
# Out:
# -192.53200000000146

# %%
#Calculating for AL MVP Shohei Ohtani
t = open('ohtani.txt','r')
newlist = []
for a in t:
    if a[1].isnumeric():
        #print(a)
        continue
    #print(a.split("	"))
    newlist.append(a.split("	"))

#print(newlist)
  
xOBP = 0

OBPmatrix = [[.354,.326,.157,0],
            [.336,.344,.164,0],
            [.353,.341,.180,0],
            [.927,.714,.456,0],
            [1,1,1,0]]

BIP = .326
    
for pit in newlist:
    if len(pit[0]) != 2:
        continue
    #print(pit[10], pit[12])
    if 'strike' in pit[12]:
        #print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])+1], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])] )
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'foul' in pit[12] and pit[10][2] != 2:
        #print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])+1], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])] )
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'ball' in pit[12]:
        #print(OBPmatrix[int(pit[10][0])][int(pit[10][2])], OBPmatrix[int(pit[10][0])+1][int(pit[10][2])], OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])])
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
    if 'hit' in pit[12]:
        xOBP += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - BIP
        
print(xOBP)
# Out:
# -228.77300000000247

# %%
#Calculaing for every pitcher who threw a pitch on the Mets (more efficient)
OBPmatrix = [[.354,.326,.157,0],
            [.336,.344,.164,0],
            [.353,.341,.180,0],
            [.927,.714,.456,0],
            [1,1,1,0]]

BIP = .326

f = open('mets.txt','r')
players = []
xOBP = {}
for p in f:
    k = p.split("	")
    if len(k) != 15:
        continue
    if k[3] not in players:
        players.append(k[3])
        xOBP[k[3]] = 0
    if len(k[0]) == 2:
        #print(k[12])
        if 'strike' in k[12]:
            xOBP[k[3]] += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'foul' in pit[12] and pit[10][2] != 2:
            xOBP[k[3]] += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'ball' in pit[12]:
            xOBP[k[3]] += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
        if 'hit' in pit[12]:
            xOBP[k[3]] += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - BIP

for x in xOBP:
    print(x, round(xOBP[x],3))
# Out:
# Williams, Trevor 12.734
# Syndergaard, Noah 0.664
# Gsellman, Robert 10.01
# Hembree, Heath 6.502
# Carrasco, Carlos 22.582
# Castro, Miguel 31.848
# Hand, Brad 5.886
# Megill, Tylor 39.648
# May, Trevor 29.402
# Familia, Jeurys 26.286
# DÃ­az, Edwin 25.924
# Hill, Rich 27.498
# Walker, Taijuan 66.006
# Loup, Aaron 21.772
# Lugo, Seth 19.832
# Stroman, Marcus 71.206
# Reed, Jake 2.096
# DÃ­az, Yennsy 11.21
# Hartlieb, Geoff 2.822
# Drury, Brandon 0.654
# Pillar, Kevin 0.136
# Smith, Drew 15.716
# Banda, Anthony 3.316
# Bostick, Akeem 0.364
# Eickhoff, Jerad 8.61
# Nogosek, Stephen 1.368
# Stock, Robert 2.386
# Tropeano, Nick 0.834
# deGrom, Jacob 32.66
# Oswalt, Corey 4.096
# Szapucki, Thomas 2.036
# Peterson, David 28.792
# Reid-Foley, Sean 9.674
# Almora Jr., Albert 0.644
# Lucchesi, Joey 14.82
# Barnes, Jacob 7.85
# Yamamoto, Jordan 2.726
# Hunter, Tommy 2.578
# Tarpley, Stephen 0.354
# Hildenberger, Trevor 1.464
# Guillorme, Luis 0.372
# Betances, Dellin 0.49

# %%
#increasing plot size for better visibility
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 8
plt.rcParams["figure.figsize"] = fig_size

# %%
#printing results
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = list(xOBP.keys())
students = list(xOBP.values())
ax.bar(langs,students)
plt.xticks(rotation=90)
plt.show()

# %%
#Calculating more efficently for the Mets hitters
f = open('metshitters.txt','r',encoding="utf8")
players = []
xOBP = {}

# %%
for p in f:
    k = p.split("	")
    if len(k) != 15:
        continue
    if k[4] not in players:
        players.append(k[4])
        xOBP[k[4]] = 0
    if len(k[0]) == 2:
        #print(k[12])
        if 'strike' in k[12]:
            xOBP[k[4]] += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'foul' in pit[12] and pit[10][2] != 2:
            xOBP[k[4]] += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'ball' in pit[12]:
            xOBP[k[4]] += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
        if 'hit' in pit[12]:
            xOBP[k[4]] += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - BIP

for x in xOBP:
    print(x, round(xOBP[x],3))
# Out:
# Williams, Trevor 0.922
# Mazeika, Patrick 8.228
# Peraza, José 12.5
# Villar, Jonathan 49.312
# Smith, Dominic 46.642
# Alonso, Pete 57.444
# Conforto, Michael 49.686
# Lindor, Francisco 51.53
# Nimmo, Brandon 39.456
# Guillorme, Luis 16.714
# Carrasco, Carlos 2.046
# McCann, James 40.646
# Pillar, Kevin 33.168
# McNeil, Jeff 34.356
# Báez, Javier 18.452
# Megill, Tylor 3.706
# Hill, Rich 2.288
# Walker, Taijuan 5.78
# Stroman, Marcus 5.108
# Nido, Tomás 13.324
# Davis, J.D. 23.664
# Almora Jr., Albert 5.576
# Sisco, Chance 1.044
# Drury, Brandon 8.332
# Blankenhorn, Travis 2.374
# Reed, Jake 0.036
# Díaz, Yennsy 0.174
# Eickhoff, Jerad 0.326
# Nogosek, Stephen 0.138
# Stock, Robert 0.164
# Banda, Anthony 0.072
# Smith, Drew 0.182
# McKinney, Billy 11.406
# Tropeano, Nick 0.11
# deGrom, Jacob 2.632
# Peterson, David 2.244
# Szapucki, Thomas 0.11
# Oswalt, Corey 0.082
# Williams, Mason 3.368
# Lucchesi, Joey 1.364
# Reid-Foley, Sean 0.236
# Lugo, Seth 0.082
# Gsellman, Robert 0.888
# ...

# %%
#printing results
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = list(xOBP.keys())
students = list(xOBP.values())
ax.bar(langs,students)
plt.xticks(rotation=90)
plt.show()

# %%
#Calculating results for the Dodgers and Giants, the 2 most successful regular season teams in 2021
OBPmatrix = [[.354,.326,.157,0],
            [.336,.344,.164,0],
            [.353,.341,.180,0],
            [.927,.714,.456,0],
            [1,1,1,0]]

BIP = .326

f = open('bestteams.txt','r',encoding="utf8")
players = []
xOBP = {}
for p in f:
    k = p.split("	")
    if len(k) != 15:
        continue
    if k[3] not in players:
        players.append(k[3])
        xOBP[k[3]] = 0
    if len(k[0]) == 2:
        #print(k[12])
        if 'strike' in k[12]:
            xOBP[k[3]] += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'foul' in pit[12] and pit[10][2] != 2:
            xOBP[k[3]] += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'ball' in pit[12]:
            xOBP[k[3]] += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - OBPmatrix[int(pit[10][0])+1][int(pit[10][2])]
        if 'hit' in pit[12]:
            xOBP[k[3]] += OBPmatrix[int(pit[10][0])][int(pit[10][2])] - BIP

for x in xOBP:
    print(x, round(xOBP[x],3))
# Out:
# Buehler, Walker 83.0
# Jackson, Andre 5.066
# Bickford, Phil 19.376
# Bruihl, Justin 6.27
# Urías, Julio 73.388
# Price, David 30.024
# White, Mitch 18.02
# Kershaw, Clayton 49.14
# Kelly, Joe 19.218
# Jansen, Kenley 28.798
# Graterol, Brusdar 13.222
# Vesia, Alex 17.28
# Phillips, Evan 5.158
# Treinen, Blake 28.148
# Gonsolin, Tony 25.688
# Knebel, Corey 10.514
# Scherzer, Max 27.6
# Greene, Shane 3.308
# Feliz, Neftalí 0.846
# Vasquez, Andrew 0.738
# Turner, Justin 0.264
# González, Victor 14.14
# Uceta, Edwin 9.086
# Núñez, Darien 3.266
# Greene, Conner 0.672
# Quackenbush, Kevin 0.5
# Cleavinger, Garrett 9.16
# Ramírez, Yefry 0.582
# Nelson, Jimmy 14.286
# Gray, Josiah 4.404
# Sherfy, Jimmie 6.296
# Alexander, Scott 6.51
# Reed, Jake 2.296
# Bauer, Trevor 44.95
# Jones, Nate 2.908
# Burns, Andy 0.628
# Santana, Dennis 6.75
# Kickham, Mike 1.062
# May, Dustin 10.124
# Webb, Logan 59.032
# Castro, Kervin 5.466
# Leone, Dominic 22.01
# García, Jarlín 26.464
# Gausman, Kevin 80.16
# ...

# %%
#Printing Dodger results
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = list(xOBP.keys())
students = list(xOBP.values())
ax.bar(langs[0:37],students[0:37])
plt.xticks(rotation=90)
plt.show()

# %%
#printing Giants results
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = list(xOBP.keys())
students = list(xOBP.values())
ax.bar(langs[37:70],students[37:70])
plt.xticks(rotation=90)
plt.show()

# %%
#Expanding to AVG for mets pitchers
AVGmatrix = [[.343,.317,.146,0],
            [.331,.349,.155,0],
            [.350,.337,.172,0],
            [.384,.348,.199,0],
            [1,1,1,0]]

BIP = .330

f = open('mets.txt','r',encoding="utf8")
players = []
xOBP = {}
for p in f:
    k = p.split("	")
    if len(k) != 15:
        continue
    if k[3] not in players:
        players.append(k[3])
        xOBP[k[3]] = 0
    if len(k[0]) == 2:
        #print(k[12])
        if 'strike' in k[12]:
            xOBP[k[3]] += AVGmatrix[int(pit[10][0])][int(pit[10][2])] - AVGmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'foul' in pit[12] and pit[10][2] != 2:
            xOBP[k[3]] += AVGmatrix[int(pit[10][0])][int(pit[10][2])] - AVGmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'ball' in pit[12]:
            xOBP[k[3]] += AVGmatrix[int(pit[10][0])][int(pit[10][2])] - AVGmatrix[int(pit[10][0])+1][int(pit[10][2])]
        if 'hit' in pit[12]:
            xOBP[k[3]] += AVGmatrix[int(pit[10][0])][int(pit[10][2])] - BIP

for x in xOBP:
    print(x, round(xOBP[x],3))
# Out:
# Williams, Trevor 9.472
# Syndergaard, Noah 0.494
# Gsellman, Robert 7.348
# Hembree, Heath 4.826
# Carrasco, Carlos 16.778
# Castro, Miguel 23.916
# Hand, Brad 4.386
# Megill, Tylor 29.49
# May, Trevor 22.036
# Familia, Jeurys 19.68
# Díaz, Edwin 19.49
# Hill, Rich 20.598
# Walker, Taijuan 49.284
# Loup, Aaron 16.37
# Lugo, Seth 14.974
# Stroman, Marcus 53.198
# Reed, Jake 1.588
# Díaz, Yennsy 8.302
# Hartlieb, Geoff 2.116
# Drury, Brandon 0.48
# Pillar, Kevin 0.098
# Smith, Drew 11.746
# Banda, Anthony 2.438
# Bostick, Akeem 0.272
# Eickhoff, Jerad 6.312
# Nogosek, Stephen 1.044
# Stock, Robert 1.796
# Tropeano, Nick 0.6
# deGrom, Jacob 24.868
# Oswalt, Corey 3.068
# Szapucki, Thomas 1.504
# Peterson, David 21.446
# Reid-Foley, Sean 7.234
# Almora Jr., Albert 0.466
# Lucchesi, Joey 11.046
# Barnes, Jacob 5.842
# Yamamoto, Jordan 2.008
# Hunter, Tommy 1.88
# Tarpley, Stephen 0.258
# Hildenberger, Trevor 1.086
# Guillorme, Luis 0.27
# Betances, Dellin 0.356

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = list(xOBP.keys())
students = list(xOBP.values())
ax.bar(langs,students)
plt.xticks(rotation=90)
plt.show()

# %%
#Expanding to SLG for mets pitchers
SLGmatrix = [[.582,.512,.227,0],
            [.578,.568,.244,0],
            [.664,.596,.280,0],
            [.792,.672,.352,0],
            [1,1,1,0]]

BIP = .555

f = open('mets.txt','r',encoding="utf8")
players = []
xOBP = {}
for p in f:
    k = p.split("	")
    if len(k) != 15:
        continue
    if k[3] not in players:
        players.append(k[3])
        xOBP[k[3]] = 0
    if len(k[0]) == 2:
        #print(k[12])
        if 'strike' in k[12]:
            xOBP[k[3]] += SLGmatrix[int(pit[10][0])][int(pit[10][2])] - SLGmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'foul' in pit[12] and pit[10][2] != 2:
            xOBP[k[3]] += SLGmatrix[int(pit[10][0])][int(pit[10][2])] - SLGmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'ball' in pit[12]:
            xOBP[k[3]] += SLGmatrix[int(pit[10][0])][int(pit[10][2])] - SLGmatrix[int(pit[10][0])+1][int(pit[10][2])]
        if 'hit' in pit[12]:
            xOBP[k[3]] += SLGmatrix[int(pit[10][0])][int(pit[10][2])] - BIP

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = list(xOBP.keys())
students = list(xOBP.values())
ax.bar(langs,students)
plt.xticks(rotation=90)
plt.show()

# %%
#Expanding to wOBA for mets pitchers
wOBAmatrix = [[.393,.354,.165,0],
            [.383,.384,.175,0],
            [.423,.392,.196,0],
            [.668,.574,.379,0],
            [1,1,1,0]]

BIP = .370

f = open('mets.txt','r',encoding="utf8")
players = []
xOBP = {}
for p in f:
    k = p.split("	")
    if len(k) != 15:
        continue
    if k[3] not in players:
        players.append(k[3])
        xOBP[k[3]] = 0
    if len(k[0]) == 2:
        #print(k[12])
        if 'strike' in k[12]:
            xOBP[k[3]] += wOBAmatrix[int(pit[10][0])][int(pit[10][2])] - wOBAmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'foul' in pit[12] and pit[10][2] != 2:
            xOBP[k[3]] += wOBAmatrix[int(pit[10][0])][int(pit[10][2])] - wOBAmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'ball' in pit[12]:
            xOBP[k[3]] += wOBAmatrix[int(pit[10][0])][int(pit[10][2])] - wOBAmatrix[int(pit[10][0])+1][int(pit[10][2])]
        if 'hit' in pit[12]:
            xOBP[k[3]] += wOBAmatrix[int(pit[10][0])][int(pit[10][2])] - BIP

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = list(xOBP.keys())
students = list(xOBP.values())
ax.bar(langs,students)
plt.xticks(rotation=90)
plt.show()

# %%
#Expanding to AVG for mets batters
AVGmatrix = [[.343,.317,.146,0],
            [.331,.349,.155,0],
            [.350,.337,.172,0],
            [.384,.348,.199,0],
            [1,1,1,0]]

BIP = .330

f = open('metshitters.txt','r',encoding="utf8")
players = []
xOBP = {}
for p in f:
    k = p.split("	")
    if len(k) != 15:
        continue
    if k[4] not in players:
        players.append(k[4])
        xOBP[k[4]] = 0
    if len(k[0]) == 2:
        #print(k[12])
        if 'strike' in k[12]:
            xOBP[k[4]] += AVGmatrix[int(pit[10][0])][int(pit[10][2])] - AVGmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'foul' in pit[12] and pit[10][2] != 2:
            xOBP[k[4]] += AVGmatrix[int(pit[10][0])][int(pit[10][2])] - AVGmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'ball' in pit[12]:
            xOBP[k[4]] += AVGmatrix[int(pit[10][0])][int(pit[10][2])] - AVGmatrix[int(pit[10][0])+1][int(pit[10][2])]
        if 'hit' in pit[12]:
            xOBP[k[4]] += AVGmatrix[int(pit[10][0])][int(pit[10][2])] - BIP

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = list(xOBP.keys())
students = list(xOBP.values())
ax.bar(langs,students)
plt.xticks(rotation=90)
plt.show()

# %%
#Expanding to SLG for mets hitters
SLGmatrix = [[.582,.512,.227,0],
            [.578,.568,.244,0],
            [.664,.596,.280,0],
            [.792,.672,.352,0],
            [1,1,1,0]]

BIP = .555

f = open('metshitters.txt','r',encoding="utf8")
players = []
xOBP = {}
for p in f:
    k = p.split("	")
    if len(k) != 15:
        continue
    if k[4] not in players:
        players.append(k[4])
        xOBP[k[4]] = 0
    if len(k[0]) == 2:
        #print(k[12])
        if 'strike' in k[12]:
            xOBP[k[4]] += SLGmatrix[int(pit[10][0])][int(pit[10][2])] - SLGmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'foul' in pit[12] and pit[10][2] != 2:
            xOBP[k[4]] += SLGmatrix[int(pit[10][0])][int(pit[10][2])] - SLGmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'ball' in pit[12]:
            xOBP[k[4]] += SLGmatrix[int(pit[10][0])][int(pit[10][2])] - SLGmatrix[int(pit[10][0])+1][int(pit[10][2])]
        if 'hit' in pit[12]:
            xOBP[k[4]] += SLGmatrix[int(pit[10][0])][int(pit[10][2])] - BIP

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = list(xOBP.keys())
students = list(xOBP.values())
ax.bar(langs,students)
plt.xticks(rotation=90)
plt.show()

# %%
#Expanding to wOBA for mets pitchers
wOBAmatrix = [[.393,.354,.165,0],
            [.383,.384,.175,0],
            [.423,.392,.196,0],
            [.668,.574,.379,0],
            [1,1,1,0]]

BIP = .370

f = open('metshitters.txt','r',encoding="utf8")
players = []
xOBP = {}
for p in f:
    k = p.split("	")
    if len(k) != 15:
        continue
    if k[4] not in players:
        players.append(k[4])
        xOBP[k[4]] = 0
    if len(k[0]) == 2:
        #print(k[12])
        if 'strike' in k[12]:
            xOBP[k[4]] += wOBAmatrix[int(pit[10][0])][int(pit[10][2])] - wOBAmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'foul' in pit[12] and pit[10][2] != 2:
            xOBP[k[4]] += wOBAmatrix[int(pit[10][0])][int(pit[10][2])] - wOBAmatrix[int(pit[10][0])][int(pit[10][2])+1]
        if 'ball' in pit[12]:
            xOBP[k[4]] += wOBAmatrix[int(pit[10][0])][int(pit[10][2])] - wOBAmatrix[int(pit[10][0])+1][int(pit[10][2])]
        if 'hit' in pit[12]:
            xOBP[k[4]] += wOBAmatrix[int(pit[10][0])][int(pit[10][2])] - BIP

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = list(xOBP.keys())
students = list(xOBP.values())
ax.bar(langs,students)
plt.xticks(rotation=90)
plt.show()
